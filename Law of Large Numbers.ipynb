# %% [markdown]
# ### Law of Large Numbers Assignment

# %% [markdown]
# ![normaldist.PNG](attachment:normaldist.PNG)

# %%
import numpy as np
from numpy.random import randn

# %%
n=10000
counter = 0
for i in randn(n):
    if ( i > -1 and i < 1 ):
        counter += 1
ans = counter / n
print(ans)
# Out:
# 0.6734
